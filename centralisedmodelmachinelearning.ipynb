# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import warnings
# --- ADDED: Import the LR scheduler ---
from torch.optim.lr_scheduler import ReduceLROnPlateau
# --- END OF ADDITION ---

# -------------------------------------------------------------------
# CONFIGURATION
# -------------------------------------------------------------------

# --- Path to your main manifest file ---
MANIFEST_PATH = "/home/DSE423/Documents/FL Project/manifest.csv"

# --- Centralized split files ---
TRAIN_CSV_PATH = "central_train.csv"
VAL_CSV_PATH = "central_val.csv"
TEST_CSV_PATH = "central_test.csv"

# --- Model & Training Parameters ---
BATCH_SIZE = 32
NUM_EPOCHS = 5
MOMENTUM = 0.9
BEST_MODEL_PATH = "centralized_best_model.pth"
HISTORY_PLOT_PATH = "training_history.png"
LEARNING_RATE = 0.0001 

# --- Define class names (MUST match your notebook) ---
CLASS_NAMES = ['Non Demented', 'Very mild Dementia', 'Mild Dementia', 'Moderate Dementia']

# -------------------------------------------------------------------
# STEP 1: DATA SPLITTING
# -------------------------------------------------------------------
def create_centralized_splits(manifest_path):
    print("--- STEP 1: Creating Data Splits ---")
    # Check if files already exist to avoid re-splitting
    if os.path.exists(TRAIN_CSV_PATH) and os.path.exists(VAL_CSV_PATH) and os.path.exists(TEST_CSV_PATH):
        print("CSV split files already exist. Loading them.")
        train_df = pd.read_csv(TRAIN_CSV_PATH)
        val_df = pd.read_csv(VAL_CSV_PATH)
        test_df = pd.read_csv(TEST_CSV_PATH)
        print("✅ Data splits loaded.")
    else:
        print(f"Loading master manifest from {manifest_path}...")
        try:
            df = pd.read_csv(manifest_path)
        except FileNotFoundError:
            print(f"❌ ERROR: File not found at {manifest_path}")
            return False
        
        print(f"Loaded {len(df)} total records.")
        if 'label' not in df.columns:
            print("❌ ERROR: 'label' column not found in manifest.csv")
            return False
        
        print("Splitting data into stratified train (70%), val (15%), test (15%)...")
        y = df['label']
        train_df, temp_df = train_test_split(df, test_size=0.3, stratify=y, random_state=42)
        val_df, test_df = train_test_split(temp_df, test_size=0.5, stratify=temp_df['label'], random_state=42)
        
        train_df.to_csv(TRAIN_CSV_PATH, index=False)
        val_df.to_csv(VAL_CSV_PATH, index=False)
        test_df.to_csv(TEST_CSV_PATH, index=False)
        print("✅ Data splitting successful!")

    print(f"  Training set:   {len(train_df)} images")
    print(f"  Validation set: {len(val_df)} images")
    print(f"  Test set:       {len(test_df)} images")
    return True

# -------------------------------------------------------------------
# STEP 2: DEFINE THE DATASET CLASS
# -------------------------------------------------------------------
class MRIDataset(torch.utils.data.Dataset):
    def __init__(self, csv_path, transform=None):
        self.data = pd.read_csv(csv_path)
        self.transform = transform
        self.image_col = 'image_path' 
        self.label_col = 'label'

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_path = self.data.loc[idx, self.image_col]
        label_str = self.data.loc[idx, self.label_col]
        
        try:
            image = Image.open(img_path).convert("RGB")
        except FileNotFoundError:
            warnings.warn(f"Warning: Image not found at {img_path}. Returning None.")
            return None 

        if self.transform:
            image = self.transform(image)
            
        label_map = {
            "Non Demented": 0,
            "Very mild Dementia": 1,
            "Mild Dementia": 2,
            "Moderate Dementia": 3,
        }
        label = label_map[label_str]
        
        return image, label

# -------------------------------------------------------------------
# STEP 3: DEFINE THE MODEL
# -------------------------------------------------------------------
class MRI_CNN(nn.Module):
    def __init__(self, num_classes=4):
        super(MRI_CNN, self).__init__()
        self.block1 = nn.Sequential(
            nn.Conv2d(3, 32, 3, 1, 1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.block2 = nn.Sequential(
            nn.Conv2d(32, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.block3 = nn.Sequential(
            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.MaxPool2d(2),
        )
        self.block4 = nn.Sequential(
            nn.Conv2d(128, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Dropout(0.4),
        )
        self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.classifier = nn.Sequential(
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes),
        )

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        x = self.global_avg_pool(x)
        x = x.view(x.size(0), -1)
        return self.classifier(x)

# -------------------------------------------------------------------
# STEP 4: DEFINE TRANSFORMS
# -------------------------------------------------------------------
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3),
])

# -------------------------------------------------------------------
# STEP 5: TRAINING & VALIDATION FUNCTIONS
# -------------------------------------------------------------------
def train_one_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct_preds = 0
    total_preds = 0
    
    for (images, labels) in tqdm(dataloader, desc="Training", leave=False):
        if images is None or labels is None or images.numel() == 0:
            continue
            
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * images.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total_preds += labels.size(0)
        correct_preds += (predicted == labels).sum().item()

    epoch_loss = running_loss / total_preds if total_preds > 0 else 0
    epoch_acc = correct_preds / total_preds if total_preds > 0 else 0
    return epoch_loss, epoch_acc

def validate(model, dataloader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct_preds = 0
    total_preds = 0
    
    with torch.no_grad():
        for (images, labels) in tqdm(dataloader, desc="Validation", leave=False):
            if images is None or labels is None or images.numel() == 0:
                continue

            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * images.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total_preds += labels.size(0)
            correct_preds += (predicted == labels).sum().item()

    epoch_loss = running_loss / total_preds if total_preds > 0 else 0
    epoch_acc = correct_preds / total_preds if total_preds > 0 else 0
    return epoch_loss, epoch_acc

# -------------------------------------------------------------------
# STEP 6: HELPER FUNCTIONS (Collate, Plotting)
# -------------------------------------------------------------------
def collate_fn(batch):
    batch = list(filter(lambda x: x is not None, batch))
    if not batch:
        return None, None
    return torch.utils.data.dataloader.default_collate(batch)

def plot_confusion_matrix_heatmap(cm, class_names):
    plt.figure(figsize=(10, 8))
    sns.heatmap(
        cm, 
        annot=True, 
        fmt='d', 
        cmap='Blues', 
        xticklabels=class_names, 
        yticklabels=class_names
    )
    plt.title('Centralized Model Confusion Matrix (Test Set)')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.savefig('centralized_confusion_matrix.png')
    print("Confusion matrix saved to 'centralized_confusion_matrix.png'")

def plot_training_history(history):
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 12))
    fig.suptitle('Centralized Model Training History', fontsize=16, y=1.02)
    
    # Plot Loss
    ax1.plot(history['train_loss'], label='Train Loss')
    ax1.plot(history['val_loss'], label='Validation Loss')
    ax1.set_title('Model Loss per Epoch')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.legend()
    ax1.grid(True)
    
    # Plot Accuracy
    ax2.plot(history['train_acc'], label='Train Accuracy')
    ax2.plot(history['val_acc'], label='Validation Accuracy')
    ax2.set_title('Model Accuracy per Epoch')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.legend()
    ax2.grid(True)
    
    plt.tight_layout()
    plt.savefig(HISTORY_PLOT_PATH)
    print(f"Training history plot saved to '{HISTORY_PLOT_PATH}'")

# -------------------------------------------------------------------
# STEP 7: MAIN TRAINING SCRIPT
# -------------------------------------------------------------------
def run_training_pipeline():
    print("\n--- STEP 2: Setting up Training ---")
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {DEVICE}")

    print("Loading datasets from split CSVs...")
    train_dataset = MRIDataset(csv_path=TRAIN_CSV_PATH, transform=transform)
    val_dataset = MRIDataset(csv_path=VAL_CSV_PATH, transform=transform)
    
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, collate_fn=collate_fn)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, collate_fn=collate_fn)
    
    print("Initializing model...")
    model = MRI_CNN().to(DEVICE)

    # --- ADDED: Class Weight Calculation (Change 1) ---
    print("Calculating class weights to handle imbalance...")
    # Counts based on 70% of totals from manifest (Non: 67222, VMD: 13725, MD: 5002, MOD: 488)
    count_non = 47055
    count_vmid = 9608
    count_mid = 3501
    count_mod = 342
    total = count_non + count_vmid + count_mid + count_mod

    # Formula: total / (num_classes * count)
    weights = [
        total / (4 * count_non),
        total / (4 * count_vmid),
        total / (4 * count_mid),
        total / (4 * count_mod) 
    ]
    class_weights = torch.tensor(weights).float().to(DEVICE)
    print(f"Using class weights (Non, VMD, MD, MOD): {np.round(weights, 2)}")
    # --- END OF ADDITION ---
    
    # --- MODIFIED LINE (Change 1) ---
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    # --- END OF MODIFICATION ---
    
    # Using the updated LEARNING_RATE
    optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM)
    print(f"Using optimizer: SGD (lr={LEARNING_RATE}, momentum={MOMENTUM})")
    
    # --- ADDED: Learning Rate Scheduler (Change 2) ---
    # Will reduce LR by factor of 0.1 if val_loss plateaus for 3 epochs
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.1, patience=3, verbose=True)
    print("Using ReduceLROnPlateau LR scheduler.")
    # --- END OF ADDITION ---
    
    best_val_acc = 0.0
    
    # History dictionary to store metrics
    history = {
        'train_loss': [], 'train_acc': [],
        'val_loss': [], 'val_acc': []
    }

    print(f"\n--- STEP 3: Starting Centralized Training ({NUM_EPOCHS} Epochs) ---")
    for epoch in range(NUM_EPOCHS):
        print(f"\n--- Epoch {epoch+1}/{NUM_EPOCHS} ---")
        
        train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, DEVICE)
        val_loss, val_acc = validate(model, val_loader, criterion, DEVICE)
        
        # --- ADDED: Scheduler Step (Change 2) ---
        # Tell the scheduler to check the validation loss
        scheduler.step(val_loss)
        # --- END OF ADDITION ---
        
        print(f"Epoch {epoch+1} Summary:")
        print(f"  Train Loss: {train_loss:.4f} | Train Acc: {train_acc*100:.2f}%")
        print(f"  Val Loss: {val_loss:.4f}   | Val Acc: {val_acc*100:.2f}%")
        
        # Store history
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)
        
        # Save the best model
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), BEST_MODEL_PATH)
            print(f"  🎉 New best model saved with Val Acc: {best_val_acc*100:.2f}%")

    print("--- Training Finished ---")
    
    # Plot the history
    plot_training_history(history)
    
    # -------------------------------------------------------------------
    # STEP 8: FINAL TESTING
    # -------------------------------------------------------------------
    print(f"\n--- STEP 4: Final Testing (on held-out test set) ---")
    print(f"Loading best model from {BEST_MODEL_PATH}...")
    
    # Load test set
    test_dataset = MRIDataset(csv_path=TEST_CSV_PATH, transform=transform)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, collate_fn=collate_fn)

    # Load best model weights
    # Re-initialize model first, then load state
    model = MRI_CNN().to(DEVICE) 
    model.load_state_dict(torch.load(BEST_MODEL_PATH))
    model.eval()
    
    all_labels = []
    all_preds = []
    
    with torch.no_grad():
        for (images, labels) in tqdm(test_loader, desc="Testing"):
            if images is None or labels is None or images.numel() == 0:
                continue 
            
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())
    
    # Calculate final metrics
    test_acc = accuracy_score(all_labels, all_preds)
    print(f"\n========================================================")
    print(f"📊 FINAL TEST ACCURACY: {test_acc*100:.2f}%")
    print(f"========================================================")
    
    # Generate and plot confusion matrix
    cm = confusion_matrix(all_labels, all_preds, labels=[0, 1, 2, 3])
    plot_confusion_matrix_heatmap(cm, class_names=CLASS_NAMES)
    
    print("\n--- Centralized Baseline Run Complete ---")


# -------------------------------------------------------------------
# SCRIPT EXECUTION
# -------------------------------------------------------------------
if __name__ == "__main__":
    # Suppress UserWarnings from PIL
    warnings.filterwarnings("ignore", category=UserWarning, module="PIL")
    
    # First, create the split files from the main manifest
    if create_centralized_splits(MANIFEST_PATH):
        # If splitting was successful, run the training
        run_training_pipeline()
    else:
        print("Halting execution due to error in data splitting.")
# Out:
# --- STEP 1: Creating Data Splits ---
# CSV split files already exist. Loading them.
# ✅ Data splits loaded.
#   Training set:   60505 images
#   Validation set: 12966 images
#   Test set:       12966 images
#
# --- STEP 2: Setting up Training ---
# Using device: cuda
# Loading datasets from split CSVs...
# Initializing model...
# Using optimizer: SGD (lr=0.0001, momentum=0.9)
#
# --- STEP 3: Starting Centralized Training (50 Epochs) ---
#
# --- Epoch 1/50 ---
# Epoch 1 Summary:
#   Train Loss: 0.7605 | Train Acc: 76.63%
#   Val Loss: 0.6569   | Val Acc: 77.77%
#   🎉 New best model saved with Val Acc: 77.77%
#
# --- Epoch 2/50 ---
# Epoch 2 Summary:
#   Train Loss: 0.5988 | Train Acc: 77.79%
#   Val Loss: 0.5777   | Val Acc: 77.77%
#
# --- Epoch 3/50 ---
# Epoch 3 Summary:
#   Train Loss: 0.5406 | Train Acc: 78.22%
#   Val Loss: 0.5281   | Val Acc: 78.09%
#   🎉 New best model saved with Val Acc: 78.09%
#
# --- Epoch 4/50 ---
# Epoch 4 Summary:
#   Train Loss: 0.5095 | Train Acc: 78.96%
#   Val Loss: 0.6101   | Val Acc: 79.51%
#   🎉 New best model saved with Val Acc: 79.51%
#
# --- Epoch 5/50 ---
# Epoch 5 Summary:
#   Train Loss: 0.4899 | Train Acc: 79.85%
#   Val Loss: 0.4767   | Val Acc: 80.24%
#   🎉 New best model saved with Val Acc: 80.24%
#
# --- Epoch 6/50 ---
# Epoch 6 Summary:
#   Train Loss: 0.4713 | Train Acc: 80.61%
#   Val Loss: 0.4636   | Val Acc: 81.57%
#   🎉 New best model saved with Val Acc: 81.57%
#
# --- Epoch 7/50 ---
# Epoch 7 Summary:
#   Train Loss: 0.4486 | Train Acc: 81.52%
#   Val Loss: 0.4293   | Val Acc: 82.14%
#   🎉 New best model saved with Val Acc: 82.14%
#
# --- Epoch 8/50 ---
# Epoch 8 Summary:
#   Train Loss: 0.4234 | Train Acc: 82.59%
#   Val Loss: 0.4161   | Val Acc: 81.44%
#
# --- Epoch 9/50 ---
# Epoch 9 Summary:
#   Train Loss: 0.3966 | Train Acc: 83.79%
#   Val Loss: 0.4105   | Val Acc: 81.24%
#
# --- Epoch 10/50 ---
# Epoch 10 Summary:
#   Train Loss: 0.3664 | Train Acc: 85.18%
#   Val Loss: 0.6108   | Val Acc: 78.07%
#
# --- Epoch 11/50 ---
# Epoch 11 Summary:
#   Train Loss: 0.3380 | Train Acc: 86.55%
#   Val Loss: 0.3666   | Val Acc: 83.34%
#   🎉 New best model saved with Val Acc: 83.34%
#
# --- Epoch 12/50 ---
# Epoch 12 Summary:
#   Train Loss: 0.3095 | Train Acc: 87.84%
#   Val Loss: 0.3004   | Val Acc: 89.12%
#   🎉 New best model saved with Val Acc: 89.12%
#
# --- Epoch 13/50 ---
# Epoch 13 Summary:
#   Train Loss: 0.2827 | Train Acc: 89.04%
#   Val Loss: 0.3545   | Val Acc: 84.50%
#
# --- Epoch 14/50 ---
# Epoch 14 Summary:
#   Train Loss: 0.2619 | Train Acc: 89.95%
#   Val Loss: 0.5229   | Val Acc: 80.07%
#
# --- Epoch 15/50 ---
# Epoch 15 Summary:
#   Train Loss: 0.2456 | Train Acc: 90.41%
#   Val Loss: 1.9088   | Val Acc: 26.79%
#
# --- Epoch 16/50 ---
# Epoch 16 Summary:
#   Train Loss: 0.2267 | Train Acc: 91.18%
#   Val Loss: 0.3432   | Val Acc: 84.58%
#
# --- Epoch 17/50 ---
# Epoch 17 Summary:
#   Train Loss: 0.2171 | Train Acc: 91.47%
#   Val Loss: 0.2566   | Val Acc: 90.57%
#   🎉 New best model saved with Val Acc: 90.57%
#
# --- Epoch 18/50 ---
# Epoch 18 Summary:
#   Train Loss: 0.2095 | Train Acc: 91.71%
#   Val Loss: 0.5408   | Val Acc: 77.66%
#
# --- Epoch 19/50 ---
# Epoch 19 Summary:
#   Train Loss: 0.1974 | Train Acc: 92.15%
#   Val Loss: 0.1969   | Val Acc: 92.69%
#   🎉 New best model saved with Val Acc: 92.69%
#
# --- Epoch 20/50 ---
# Epoch 20 Summary:
#   Train Loss: 0.1875 | Train Acc: 92.39%
#   Val Loss: 0.2099   | Val Acc: 91.79%
#
# --- Epoch 21/50 ---
# Epoch 21 Summary:
#   Train Loss: 0.1811 | Train Acc: 92.64%
#   Val Loss: 0.1857   | Val Acc: 93.03%
#   🎉 New best model saved with Val Acc: 93.03%
#
# --- Epoch 22/50 ---
# Epoch 22 Summary:
#   Train Loss: 0.1738 | Train Acc: 92.87%
#   Val Loss: 1.5460   | Val Acc: 77.80%
#
# --- Epoch 23/50 ---
# Epoch 23 Summary:
#   Train Loss: 0.1689 | Train Acc: 93.02%
#   Val Loss: 0.3821   | Val Acc: 84.12%
#
# --- Epoch 24/50 ---
# Epoch 24 Summary:
#   Train Loss: 0.1622 | Train Acc: 93.30%
#   Val Loss: 0.2765   | Val Acc: 87.47%
#
# --- Epoch 25/50 ---
# Epoch 25 Summary:
#   Train Loss: 0.1560 | Train Acc: 93.64%
#   Val Loss: 0.1602   | Val Acc: 93.92%
#   🎉 New best model saved with Val Acc: 93.92%
#
# --- Epoch 26/50 ---
# Epoch 26 Summary:
#   Train Loss: 0.1474 | Train Acc: 94.06%
#   Val Loss: 0.6142   | Val Acc: 74.88%
#
# --- Epoch 27/50 ---
# Epoch 27 Summary:
#   Train Loss: 0.1401 | Train Acc: 94.58%
#   Val Loss: 0.1557   | Val Acc: 95.17%
#   🎉 New best model saved with Val Acc: 95.17%
#
# --- Epoch 28/50 ---
# Epoch 28 Summary:
#   Train Loss: 0.1348 | Train Acc: 94.91%
#   Val Loss: 0.1890   | Val Acc: 93.63%
#
# --- Epoch 29/50 ---
# Epoch 29 Summary:
#   Train Loss: 0.1260 | Train Acc: 95.52%
#   Val Loss: 1.2274   | Val Acc: 78.06%
#
# --- Epoch 30/50 ---
# Epoch 30 Summary:
#   Train Loss: 0.1199 | Train Acc: 95.89%
#   Val Loss: 0.8537   | Val Acc: 65.39%
#
# --- Epoch 31/50 ---
# Epoch 31 Summary:
#   Train Loss: 0.1098 | Train Acc: 96.32%
#   Val Loss: 0.1358   | Val Acc: 93.58%
#
# --- Epoch 32/50 ---
# Epoch 32 Summary:
#   Train Loss: 0.1010 | Train Acc: 96.72%
#   Val Loss: 0.4144   | Val Acc: 84.47%
#
# --- Epoch 33/50 ---
# Epoch 33 Summary:
#   Train Loss: 0.0941 | Train Acc: 97.02%
#   Val Loss: 0.2880   | Val Acc: 89.99%
#
# --- Epoch 34/50 ---
# Epoch 34 Summary:
#   Train Loss: 0.0856 | Train Acc: 97.41%
#   Val Loss: 0.2699   | Val Acc: 89.95%
#
# --- Epoch 35/50 ---
# Epoch 35 Summary:
#   Train Loss: 0.0779 | Train Acc: 97.78%
#   Val Loss: 0.0939   | Val Acc: 98.13%
#   🎉 New best model saved with Val Acc: 98.13%
#
# --- Epoch 36/50 ---
# Epoch 36 Summary:
#   Train Loss: 0.0716 | Train Acc: 98.01%
#   Val Loss: 0.1881   | Val Acc: 92.93%
#
# --- Epoch 37/50 ---
# Epoch 37 Summary:
#   Train Loss: 0.0635 | Train Acc: 98.35%
#   Val Loss: 0.3310   | Val Acc: 87.71%
#
# --- Epoch 38/50 ---
# Epoch 38 Summary:
#   Train Loss: 0.0601 | Train Acc: 98.41%
#   Val Loss: 0.0963   | Val Acc: 96.96%
#
# --- Epoch 39/50 ---
# Epoch 39 Summary:
#   Train Loss: 0.0536 | Train Acc: 98.63%
#   Val Loss: 0.5956   | Val Acc: 76.84%
#
# --- Epoch 40/50 ---
# Epoch 40 Summary:
#   Train Loss: 0.0508 | Train Acc: 98.70%
#   Val Loss: 1.5848   | Val Acc: 49.66%
#
# --- Epoch 41/50 ---
# Epoch 41 Summary:
#   Train Loss: 0.0474 | Train Acc: 98.74%
#   Val Loss: 3.0670   | Val Acc: 28.36%
#
# --- Epoch 42/50 ---
# Epoch 42 Summary:
#   Train Loss: 0.0436 | Train Acc: 98.88%
#   Val Loss: 0.0823   | Val Acc: 96.96%
#
# --- Epoch 43/50 ---
# Epoch 43 Summary:
#   Train Loss: 0.0407 | Train Acc: 98.94%
#   Val Loss: 0.3826   | Val Acc: 85.01%
#
# --- Epoch 44/50 ---
# Epoch 44 Summary:
#   Train Loss: 0.0394 | Train Acc: 99.00%
#   Val Loss: 0.0674   | Val Acc: 97.74%
#
# --- Epoch 45/50 ---
# Epoch 45 Summary:
#   Train Loss: 0.0387 | Train Acc: 98.96%
#   Val Loss: 0.1083   | Val Acc: 96.41%
#
# --- Epoch 46/50 ---
# Epoch 46 Summary:
#   Train Loss: 0.0347 | Train Acc: 99.11%
#   Val Loss: 0.8962   | Val Acc: 79.46%
#
# --- Epoch 47/50 ---
# Epoch 47 Summary:
#   Train Loss: 0.0347 | Train Acc: 99.05%
#   Val Loss: 0.9338   | Val Acc: 66.34%
#
# --- Epoch 48/50 ---
# Epoch 48 Summary:
#   Train Loss: 0.0331 | Train Acc: 99.10%
#   Val Loss: 0.0763   | Val Acc: 97.01%
#
# --- Epoch 49/50 ---
# Epoch 49 Summary:
#   Train Loss: 0.0321 | Train Acc: 99.13%
#   Val Loss: 0.2974   | Val Acc: 87.51%
#
# --- Epoch 50/50 ---
# Epoch 50 Summary:
#   Train Loss: 0.0327 | Train Acc: 99.07%
#   Val Loss: 0.0384   | Val Acc: 99.14%
#   🎉 New best model saved with Val Acc: 99.14%
# --- Training Finished ---
# Training history plot saved to 'training_history.png'
#
# --- STEP 4: Final Testing (on held-out test set) ---
# Loading best model from centralized_best_model.pth...
# Testing: 100%|██████████| 406/406 [00:05<00:00, 70.12it/s]
# ========================================================
# 📊 FINAL TEST ACCURACY: 99.27%
# ========================================================
# Confusion matrix saved to 'centralized_confusion_matrix.png'
#
# --- Centralized Baseline Run Complete ---

# %%
import matplotlib.pyplot as plt
import numpy as np

# Epochs 1-50
epochs = list(range(1, 51))

# --- All 50 values manually copied from your log ---

train_loss_history = [
    0.5394, 0.4190, 0.3409, 0.2655, 0.1952, 0.1335, 0.0955, 0.0725, 0.0599, 0.0479,
    0.0412, 0.0398, 0.0333, 0.0280, 0.0253, 0.0201, 0.0200, 0.0173, 0.0158, 0.0146,
    0.0089, 0.0134, 0.0072, 0.0096, 0.0050, 0.0117, 0.0059, 0.0053, 0.0038, 0.0059,
    0.0035, 0.0045, 0.0040, 0.0078, 0.0023, 0.0074, 0.0048, 0.0013, 0.0032, 0.0058,
    0.0042, 0.0040, 0.0041, 0.0036, 0.0035, 0.0015, 0.0014, 0.0020, 0.0020, 0.0038
]

train_acc_history = [
    0.7900, 0.8234, 0.8592, 0.8970, 0.9291, 0.9549, 0.9693, 0.9771, 0.9810, 0.9852,
    0.9867, 0.9869, 0.9889, 0.9906, 0.9915, 0.9934, 0.9937, 0.9945, 0.9952, 0.9956,
    0.9978, 0.9962, 0.9983, 0.9971, 0.9990, 0.9963, 0.9986, 0.9986, 0.9991, 0.9984,
    0.9993, 0.9989, 0.9992, 0.9979, 0.9995, 0.9977, 0.9987, 0.9999, 0.9992, 0.9984,
    0.9988, 0.9988, 0.9989, 0.9990, 0.9991, 0.9997, 0.9998, 0.9996, 0.9995, 0.9990
]

val_loss_history = [
    0.7471, 0.4847, 0.8745, 0.5450, 0.2266, 0.3415, 1.7556, 0.0915, 2.5843, 0.6185,
    5.4664, 2.6427, 1.2807, 0.2300, 0.2612, 0.0593, 0.0971, 4.9609, 0.0216, 0.1957,
    0.0103, 0.6541, 0.0257, 0.4055, 0.8052, 0.0184, 0.0237, 0.0523, 0.0249, 0.0733,
    0.1599, 0.0102, 0.0119, 0.0204, 0.0249, 0.0182, 0.0464, 0.0134, 0.9407, 0.0468,
    0.0260, 0.1606, 0.0105, 0.0125, 0.0111, 0.0086, 0.0186, 0.0194, 0.0092, 0.5891
]

val_acc_history = [
    0.7052, 0.7977, 0.7782, 0.7652, 0.9220, 0.8589, 0.5182, 0.9725, 0.3820, 0.7319,
    0.1896, 0.3421, 0.6376, 0.9277, 0.9059, 0.9816, 0.9633, 0.2490, 0.9962, 0.9226,
    0.9990, 0.7781, 0.9935, 0.8409, 0.9072, 0.9961, 0.9940, 0.9766, 0.9931, 0.9724,
    0.9456, 0.9972, 0.9968, 0.9938, 0.9917, 0.9949, 0.9829, 0.9967, 0.7074, 0.9822,
    0.9913, 0.9368, 0.9976, 0.9962, 0.9972, 0.9974, 0.9934, 0.9942, 0.9978, 0.8430
]

# --- PLOTTING CODE ---

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 12))
fig.suptitle('Centralized Model Training History', fontsize=16, y=1.02)

# Plot Loss
ax1.plot(epochs, train_loss_history, label='Train Loss')
ax1.plot(epochs, val_loss_history, label='Validation Loss')
ax1.set_title('Model Loss per Epoch')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax1.grid(True)

# Plot Accuracy
ax2.plot(epochs, train_acc_history, label='Train Accuracy')
ax2.plot(epochs, val_acc_history, label='Validation Accuracy')
ax2.set_title('Model Accuracy per Epoch')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.savefig('centralized_training_history.png')
print("Plot saved to 'centralized_training_history.png'")
plt.show()
# Out:
# Plot saved to 'centralized_training_history.png'

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import accuracy_score, confusion_matrix
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import warnings

# -------------------------------------------------------------------
# CONFIGURATION (Redefining for this new cell)
# -------------------------------------------------------------------
# Make sure these variables match your original script
BATCH_SIZE = 32
BEST_MODEL_PATH = "centralized_best_model.pth"
TEST_CSV_PATH = "central_test.csv"
CLASS_NAMES = ['Non Demented', 'Very mild Dementia', 'Mild Dementia', 'Moderate Dementia']
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# -------------------------------------------------------------------
# MODEL DEFINITION (Must redefine the class)
# -------------------------------------------------------------------
class MRI_CNN(nn.Module):
    def __init__(self, num_classes=4):
        super(MRI_CNN, self).__init__()
        self.block1 = nn.Sequential(
            nn.Conv2d(3, 32, 3, 1, 1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.block2 = nn.Sequential(
            nn.Conv2d(32, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.block3 = nn.Sequential(
            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.MaxPool2d(2),
        )
        self.block4 = nn.Sequential(
            nn.Conv2d(128, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Dropout(0.4),
        )
        self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.classifier = nn.Sequential(
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes),
        )

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        x = self.global_avg_pool(x)
        x = x.view(x.size(0), -1)
        return self.classifier(x)

# -------------------------------------------------------------------
# DATASET/TRANSFORM DEFINITIONS (Must redefine)
# -------------------------------------------------------------------
class MRIDataset(torch.utils.data.Dataset):
    def __init__(self, csv_path, transform=None):
        self.data = pd.read_csv(csv_path)
        self.transform = transform
        self.image_col = 'image_path' 
        self.label_col = 'label'

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_path = self.data.loc[idx, self.image_col]
        label_str = self.data.loc[idx, self.label_col]
        
        try:
            image = Image.open(img_path).convert("RGB")
        except FileNotFoundError:
            warnings.warn(f"Warning: Image not found at {img_path}. Returning None.")
            return None

        if self.transform:
            image = self.transform(image)
            
        label_map = {
            "Non Demented": 0,
            "Very mild Dementia": 1,
            "Mild Dementia": 2,
            "Moderate Dementia": 3,
        }
        label = label_map[label_str]
        
        return image, label

transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3),
])

# -------------------------------------------------------------------
# HELPER FUNCTION DEFINITIONS (Must redefine)
# -------------------------------------------------------------------
def collate_fn(batch):
    # Filter out None values
    batch = list(filter(lambda x: x is not None, batch))
    if not batch:
        return None, None
    # Use default collate to stack tensors
    return torch.utils.data.dataloader.default_collate(batch)

def plot_confusion_matrix_heatmap(cm, class_names):
    plt.figure(figsize=(10, 8))
    sns.heatmap(
        cm, 
        annot=True, 
        fmt='d', 
        cmap='Blues', 
        xticklabels=class_names, 
        yticklabels=class_names
    )
    plt.title('Centralized Model Confusion Matrix (Test Set)')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.savefig('centralized_confusion_matrix.png')
    print("Confusion matrix saved to 'centralized_confusion_matrix.png'")

# -------------------------------------------------------------------
# FINAL TESTING SCRIPT
# -------------------------------------------------------------------
print(f"\n--- Running Final Test ---")
print(f"Loading best model from {BEST_MODEL_PATH}...")
print(f"Using device: {DEVICE}")

# Suppress warnings for cleaner output
warnings.filterwarnings("ignore", category=UserWarning, module="PIL")

try:
    # Load test set
    # --- This includes the fix: 'csv_path' ---
    test_dataset = MRIDataset(csv_path=TEST_CSV_PATH, transform=transform)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, collate_fn=collate_fn)

    # Load best model weights
    model = MRI_CNN().to(DEVICE)
    model.load_state_dict(torch.load(BEST_MODEL_PATH))
    model.eval()

    all_labels = []
    all_preds = []

    with torch.no_grad():
        for (images, labels) in tqdm(test_loader, desc="Testing"):
            # Check for empty batches filtered by collate_fn
            if images is None or labels is None or images.numel() == 0:
                continue
            
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())

    # Calculate final metrics
    test_acc = accuracy_score(all_labels, all_preds)
    print(f"\n========================================================")
    print(f"📊 FINAL TEST ACCURACY: {test_acc*100:.2f}%")
    print(f"========================================================")

    # Generate and plot confusion matrix
    cm = confusion_matrix(all_labels, all_preds, labels=[0, 1, 2, 3])
    plot_confusion_matrix_heatmap(cm, class_names=CLASS_NAMES)

    print("\n--- Centralized Baseline Test Complete ---")

except FileNotFoundError:
    print(f"❌ ERROR: File not found. Could not find '{BEST_MODEL_PATH}' or '{TEST_CSV_PATH}'.")
    print("Please make sure these files are in the same directory as your script.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# --- Running Final Test ---
# Loading best model from centralized_best_model.pth...
# Using device: cuda
# Testing:   0%|          | 0/406 [00:00<?, ?it/s]
# Testing: 100%|██████████| 406/406 [00:05<00:00, 70.40it/s]
# ========================================================
# 📊 FINAL TEST ACCURACY: 99.96%
# ========================================================
# Confusion matrix saved to 'centralized_confusion_matrix.png'
#
# --- Centralized Baseline Test Complete ---

# %%
import pandas as pd

# Define the paths to your split files
TRAIN_CSV_PATH = "central_train.csv"
VAL_CSV_PATH = "central_val.csv"
TEST_CSV_PATH = "central_test.csv"

print("--- Starting Data Leakage Check ---")

try:
    # Load the CSVs
    train_df = pd.read_csv(TRAIN_CSV_PATH)
    val_df = pd.read_csv(VAL_CSV_PATH)
    test_df = pd.read_csv(TEST_CSV_PATH)

    # Convert the image path columns to sets for fast comparison
    train_paths = set(train_df['image_path'])
    val_paths = set(val_df['image_path'])
    test_paths = set(test_df['image_path'])
    
    print(f"Total images in train set: {len(train_paths)}")
    print(f"Total images in validation set: {len(val_paths)}")
    print(f"Total images in test set: {len(test_paths)}")
    print("------------------------------------------")

    # Find the intersections (the leaks)
    leak_train_val = train_paths.intersection(val_paths)
    leak_train_test = train_paths.intersection(test_paths)
    leak_val_test = val_paths.intersection(test_paths)
    
    is_leaked = False
    
    # Report findings
    if len(leak_train_val) > 0:
        print(f"❌ LEAKAGE FOUND between Train and Validation: {len(leak_train_val)} overlapping images.")
        is_leaked = True
        
    if len(leak_train_test) > 0:
        print(f"❌ CRITICAL LEAKAGE FOUND between Train and Test: {len(leak_train_test)} overlapping images.")
        is_leaked = True

    if len(leak_val_test) > 0:
        print(f"❌ LEAKAGE FOUND between Validation and Test: {len(leak_val_test)} overlapping images.")
        is_leaked = True

    if not is_leaked:
        print("✅ SUCCESS: No data leakage found! Your sets are unique.")
    else:
        print("\nThis leakage is why you are seeing an impossibly high test score.")

    print("------------------------------------------")


except FileNotFoundError as e:
    print(f"❌ ERROR: File not found. Make sure all three CSV files exist.")
    print(e)
# Out:
# --- Starting Data Leakage Check ---
# Total images in train set: 60505
# Total images in validation set: 12966
# Total images in test set: 12966
# ------------------------------------------
# ✅ SUCCESS: No data leakage found! Your sets are unique.
# ------------------------------------------
